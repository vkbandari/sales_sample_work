# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('1-days_to_deliver_from_ship 5.csv')

# %%
df.sample(10)
# Out:
#               document_type order_month order_type     shipnode_key  \
# 1476         Purchase Order     2020-05   STANDARD  1014_0008003000
# 56250  Consumer Sales Order     2020-04   CONSUMER              ESW
# 53132        Purchase Order     2020-05   STANDARD  1084_0008008000
# 35276        Purchase Order     2020-05   STANDARD           BZNIKE
# 38190        Purchase Order     2020-04   STANDARD          1064_GA
# 23788           Sales Order     2020-04   STANDARD              LDC
# 22979        Purchase Order     2020-04   STANDARD  1014_0008000002
# 53212        Purchase Order     2020-05   STANDARD  1083_0008008000
# 22691        Purchase Order     2020-04   STANDARD  1065_0008000026
# 14208        Purchase Order     2020-04   STANDARD  1014_0008000002
#
#       carrier_service_code requested_delivery_date delivery_method  \
# 1476          Next Day Air                 00:00.0             SHP
# 56250       Ground Service                 00:00.0             SHP
# ...

# %%
df['carrier_service_code'].unique()
# Out:
# array(['Ground Service', 'Next Day Air', 'Two Day Air', 'Saturday',
#        'Two Day Air Upgrade', 'DEFAULT', 'Expedited', 'Next Day', nan,
#        'Z1'], dtype=object)

# %%
int(df['order_month'].unique()[1].split('-')[1])
# Out:
# 5

# %%
df.shape
# Out:
# (65534, 13)

# %%
month = []
for i in df['order_month'].str.split('-'):
    #print(i[1])
    month.append(int(i[1]))

# %%
df['month'] = month

# %%
df.columns
# Out:
# Index(['document_type', 'order_month', 'order_type', 'shipnode_key',
#        'carrier_service_code', 'requested_delivery_date', 'delivery_method',
#        'extn_order_no', 'extn_tracking_no', 'carrier', 'region',
#        'extn_ship_ts', 'extn_delivered_ts', 'month'],
#       dtype='object')

# %%
df['month'].unique()
# Out:
# array([ 4,  5,  3, 11,  2,  6,  1], dtype=int64)

# %%
df['carrier_service_code'].isnull().sum()
# Out:
# 108

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (65426, 14)

# %%
df1['carrier_service_code'].isnull().sum()
# Out:
# 0

# %%
df1['document_type'].isnull().sum()
# Out:
# 0

# %%
df1['region'].isnull().sum()
# Out:
# 0

# %%
df1['carrier'].isnull().sum()
# Out:
# 0

# %%
df2 = df1.drop(['order_month','requested_delivery_date', 'shipnode_key','extn_order_no', 'extn_tracking_no', 'extn_ship_ts','extn_delivered_ts'],axis ='columns')

# %%
df2.head(5)
# Out:
#           document_type order_type carrier_service_code delivery_method  \
# 0  Consumer Sales Order   CONSUMER       Ground Service             SHP
# 1  Consumer Sales Order   CONSUMER       Ground Service             SHP
# 2  Consumer Sales Order   CONSUMER       Ground Service             SHP
# 3  Consumer Sales Order   CONSUMER       Ground Service             SHP
# 4  Consumer Sales Order   CONSUMER       Ground Service             SHP
#
#       carrier  region  month
# 0  eSWCarrier  NIKEGS      4
# 1  eSWCarrier  NIKEGS      4
# 2  eSWCarrier  NIKEGS      4
# 3  eSWCarrier  NIKEGS      4
# 4  eSWCarrier  NIKEXA      4

# %%
df2.isnull().any()
# Out:
# document_type           False
# order_type              False
# carrier_service_code    False
# delivery_method         False
# carrier                 False
# region                  False
# month                   False
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df3 = df2.copy()

# %%
encoder1 = LabelEncoder()
df3['document_type'] = encoder1.fit_transform(df3['document_type'])

encoder1.classes_
# Out:
# array(['Consumer Sales Order', 'Purchase Order', 'Sales Order'],
#       dtype=object)

# %%
df3.head()
# Out:
#    document_type order_type carrier_service_code delivery_method     carrier  \
# 0              0   CONSUMER       Ground Service             SHP  eSWCarrier
# 1              0   CONSUMER       Ground Service             SHP  eSWCarrier
# 2              0   CONSUMER       Ground Service             SHP  eSWCarrier
# 3              0   CONSUMER       Ground Service             SHP  eSWCarrier
# 4              0   CONSUMER       Ground Service             SHP  eSWCarrier
#
#    region  month
# 0  NIKEGS      4
# 1  NIKEGS      4
# 2  NIKEGS      4
# 3  NIKEGS      4
# 4  NIKEXA      4

# %%
encoder2 = LabelEncoder()
df3['order_type'] = encoder2.fit_transform(df3['order_type'])

encoder2.classes_
# Out:
# array(['COD', 'CONSUMER', 'CONV_STORE', 'CSRORDER', 'RTBT', 'STANDARD',
#        'STORE'], dtype=object)

# %%
encoder3 = LabelEncoder()
df3['carrier_service_code'] = encoder3.fit_transform(df3['carrier_service_code'])

encoder3.classes_
# Out:
# array(['DEFAULT', 'Expedited', 'Ground Service', 'Next Day',
#        'Next Day Air', 'Saturday', 'Two Day Air', 'Two Day Air Upgrade',
#        'Z1'], dtype=object)

# %%
encoder4 = LabelEncoder()
df3['delivery_method'] = encoder4.fit_transform(df3['delivery_method'])

encoder4.classes_
# Out:
# array(['SHP'], dtype=object)

# %%
encoder5 = LabelEncoder()
df3['carrier'] = encoder5.fit_transform(df3['carrier'])

encoder5.classes_
# Out:
# array(['BRTI', 'DHID', 'DPD2', 'DPDG', 'DPDI', 'DPDM', 'DPDS', 'DPDU',
#        'DPDZ', 'EMS', 'FDE', 'SAGA', 'SEUR', 'SF', 'UPCB', 'UPSB', 'UPSH',
#        'UPSN', 'ZASS', 'eSWCarrier'], dtype=object)

# %%
encoder6 = LabelEncoder()
df3['region'] = encoder6.fit_transform(df3['region'])

encoder6.classes_
# Out:
# array(['JDSPORTS', 'NIKECN', 'NIKEEUROPE', 'NIKEGS', 'NIKEJP', 'NIKEUS',
#        'NIKEXA', 'PERRY', 'PRODIRECT', 'WHOLESALEUS', 'ZALANDOEU'],
#       dtype=object)

# %%
df3.head(2)
# Out:
#    document_type  order_type  carrier_service_code  delivery_method  carrier  \
# 0              0           1                     2                0       19
# 1              0           1                     2                0       19
#
#    region  month
# 0       3      4
# 1       3      4

# %%
x = df3.drop(['month'],axis='columns')

# %%
x.head()
# Out:
#    document_type  order_type  carrier_service_code  delivery_method  carrier  \
# 0              0           1                     2                0       19
# 1              0           1                     2                0       19
# 2              0           1                     2                0       19
# 3              0           1                     2                0       19
# 4              0           1                     2                0       19
#
#    region
# 0       3
# 1       3
# 2       3
# 3       3
# 4       6

# %%
y = df3['month']

# %%
x.shape
# Out:
# (65426, 6)

# %%
y.shape
# Out:
# (65426,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=30)

# %%
X_train
# Out:
#   File "<ipython-input-178-7240723e9151>", line 1
#     X_train.reshape(:,new_axis)
#                     ^
# SyntaxError: invalid syntax

# %%
X_test
# Out:
#        document_type  order_type  carrier_service_code  delivery_method  \
# 55253              1           5                     4                0
# 50045              1           5                     2                0
# 48150              1           5                     6                0
# 44218              2           5                     6                0
# 57711              1           5                     2                0
# ...              ...         ...                   ...              ...
# 53531              2           5                     7                0
# 18575              1           5                     2                0
# 22212              1           5                     4                0
# 15186              0           1                     2                0
# 13369              1           5                     5                0
#
#        carrier  region
# 55253        7       2
# 50045       11       4
# 48150       10       5
# ...

# %%
y_train
# Out:
# 37734    4
# 21509    4
# 12936    4
# 30233    5
# 62819    4
#         ..
# 33301    4
# 44909    4
# 48109    4
# 4517     4
# 38733    4
# Name: month, Length: 52340, dtype: int64

# %%
y_test
# Out:
# 55253    4
# 50045    4
# 48150    4
# 44218    4
# 57711    4
#         ..
# 53531    4
# 18575    4
# 22212    4
# 15186    4
# 13369    4
# Name: month, Length: 13086, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier 
knc = KNeighborsClassifier(n_neighbors=5)
knc.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred = knc.predict(X_test)

# %%
for i,j in zip(y_pred,y_test):
    print('pred : ',i,'\tactual : ',j,'\n')
# Out:
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  5 	actual :  5
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  5
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  5
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  5
#
# pred :  4 	actual :  5
#
# pred :  4 	actual :  5
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# pred :  4 	actual :  4
#
# ...
